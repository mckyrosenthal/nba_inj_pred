# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

import sklearn

from sklearn.preprocessing import scale
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelEncoder

import sklearn.preprocessing

from sklearn.model_selection import train_test_split
from sklearn import model_selection
from sklearn import metrics

mpl.rcParams['font.family'] = "serif"
mpl.rcParams['text.usetex'] = True
mpl.rcParams['ytick.right'] = True
mpl.rcParams['ytick.direction'] = "in"
mpl.rcParams['xtick.top'] = True
mpl.rcParams['xtick.direction'] = "in"
mpl.rcParams['axes.titlesize'] = 20
mpl.rcParams['axes.labelsize'] = 20
mpl.rcParams['xtick.labelsize'] = 16
mpl.rcParams['ytick.labelsize'] = 16
mpl.rcParams['legend.fontsize'] = 20
mpl.rcParams['figure.dpi'] = 100
mpl.rcParams['savefig.dpi'] = 100
mpl.rcParams['figure.figsize'] = (6,4)
plt.rcParams['axes.labelweight'] = 'bold'
mpl.rcParams['text.latex.preamble']=[r"\usepackage{amsmath}"]    

def y_by_x(self, y, x, width=1):
    ''' Group dataframe values y by values x binned by width. Default binning of x is 1.
    x and y can be column names or transformations interpretable by the eval method.  
    '''
    grps = self.eval(x).apply(lambda t: int(t/float(width))*float(width) if not pd.isna(t) else t) 
    values = self.eval(y)
    return values.groupby(grps)

pd.DataFrame.y_by_x = y_by_x

def plot_pd_series(series, **kwargs):
    plt.plot(series.index, series.values, **kwargs, marker='o')
    
def find_nearest_idx(array, value):
    array = np.asarray(array)
    idx = (np.abs(array - value)).argmin()
    return idx

# %%
injs = pd.read_csv('inj_data_final.csv')
injs.drop(columns=['Unnamed: 0','Opp','Team'],inplace=True)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3049: DtypeWarning: Columns (104,113,122) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
enc = OneHotEncoder(sparse=False)
vals = enc.fit_transform(injs[['Position','Pos3','Shoots']])
cols = []
for cat in enc.categories_:
    cols = np.concatenate((cols,cat))
oneHot_cols = pd.DataFrame(vals,columns=cols)
injs = pd.concat((injs,oneHot_cols),axis=1)
injs.fillna(value=0,inplace=True) #Fill NaNs with 0
injs = injs.loc[injs['Name']!=0]

# %%
col_dict = {}
col_dict['Was_Injured?'] = 'Was_Injured'

for c in injs.columns:
    strng = c.replace(' ','_')
    strng = strng.replace('.','')
    strng = strng.replace('%','_per')
    if strng != c:
        col_dict[c] = strng

injs.rename(columns=col_dict,inplace=True)

# %%
injs.drop(columns=['Position','Pos3','Shoots'],inplace=True)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
y = injs['Was_Injured']
X = injs.drop(columns=['Was_Injured','Dist_Feet_Av_7','Dist_Feet_Av_14','Dist_Feet_Av_21','Date','Name'])

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)

clf = DecisionTreeClassifier()
clf.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
predicted = clf.predict(X_test)

# %%
print(metrics.accuracy_score(y_test, predicted))
print(metrics.classification_report(y_test, predicted))

cm = metrics.confusion_matrix(y_test,predicted)
print(cm)

print(metrics.f1_score(y_test, predicted))
# Out:
# 0.9366057472646387
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.96      0.97     32321
#          1.0       0.04      0.05      0.05       947
#
#     accuracy                           0.94     33268
#    macro avg       0.51      0.51      0.51     33268
# weighted avg       0.95      0.94      0.94     33268
#
# [[31107  1214]
#  [  895    52]]
# 0.04699502937189336

# %%
coeffs = pd.DataFrame(zip(X.columns, np.transpose(clf.feature_importances_)))
sort_df = coeffs.loc[coeffs[1].abs().argsort()[::-1]].reset_index()

# %%
sort_df
# Out:
#      index                                                  0         1
# 0        2                                                Age  0.029633
# 1       23                                            +/-_Av7  0.017776
# 2       64                                            PF_Av21  0.017323
# 3       45                                           +/-_Av14  0.015908
# 4       67                                           +/-_Av21  0.015787
# 5      116                                Avg_Speed_Def_Av_21  0.014936
# 6      100                                 Avg_Speed_Def_Av_7  0.014836
# 7       56                                        FT_per_Av21  0.013832
# 8       22                                           GmSc_Av7  0.013795
# 9       98                                     Avg_Speed_Av_7  0.013668
# 10       5                                            FGA_Av7  0.013618
# 11      92                                       ann_inj_rate  0.013589
# 12       6                                         FG_per_Av7  0.013533
# 13      61                                           STL_Av21  0.013420
# 14      39                                           STL_Av14  0.013296
# 15     115                                Avg_Speed_Off_Av_21  0.012925
# 16      57                                           ORB_Av21  0.012914
# 17      58                                           DRB_Av21  0.012843
# 18      28                                        FG_per_Av14  0.012823
# 19     107                                Avg_Speed_Off_Av_14  0.012414
# 20      42                                            PF_Av14  0.012230
# 21      50                                        FG_per_Av21  0.011642
# 22      44                                          GmSc_Av14  0.011620
# 23      47                                            MP_Av21  0.011552
# 24      34                                        FT_per_Av14  0.011541
# 25      35                                           ORB_Av14  0.011492
# 26       3                                             MP_Av7  0.011445
# 27      60                                           AST_Av21  0.011110
# 28      20                                             PF_Av7  0.011086
# 29      99                                 Avg_Speed_Off_Av_7  0.010686
# ..     ...                                                ...       ...
# 108    135                                               Left  0.001666
# 109    130                                      Small_Forward  0.001604
# 110    134                                               Wing  0.001293
# 111     83                                            STL_b2b  0.001261
# 112    121                     Point_Guard_and_Shooting_Guard  0.001155
# 113     80                                            DRB_b2b  0.001115
# 114     78                                         FT_per_b2b  0.001018
# 115     75                                         3P_per_b2b  0.000983
# 116    117                                             Center  0.000978
# 117     79                                            ORB_b2b  0.000973
# 118    119         Center_and_Power_Forward_and_Small_Forward  0.000968
# 119    131                   Small_Forward_and_Shooting_Guard  0.000908
# 120    132                                                Big  0.000892
# 121     77                                            FTA_b2b  0.000833
# 122     73                                             3P_b2b  0.000745
# 123     85                                            TOV_b2b  0.000730
# 124    120                                        Point_Guard  0.000729
# 125    129                                     Shooting_Guard  0.000710
# 126     76                                             FT_b2b  0.000682
# 127    133                                              Guard  0.000642
# 128    137                                              Right  0.000623
# 129    128  Power_Forward_and_Small_Forward_and_Shooting_G...  0.000613
# 130     70                                             FG_b2b  0.000571
# 131    123   Point_Guard_and_Small_Forward_and_Shooting_Guard  0.000556
# 132    118                           Center_and_Power_Forward  0.000325
# 133    125  Power_Forward_and_Point_Guard_and_Small_Forwar...  0.000186
# 134    126                   Power_Forward_and_Shooting_Guard  0.000159
# 135    136                                         Left_Right  0.000079
# 136    122                      Point_Guard_and_Small_Forward  0.000000
# 137     90                                                b2b  0.000000
#
# [138 rows x 3 columns]

# %% [markdown]
# ### How do we use with just the $N$ best performing features?

# %%
N_features = [10,20,30,40,50]
folds = 5
f1_scores = np.zeros((len(N_features),folds))

for i,N in enumerate(N_features):

    X_slice = X[sort_df[0][:N]]
    
    print(N)
    
    model= DecisionTreeClassifier()
    scores = model_selection.cross_validate(model, X_slice, y, cv=folds,scoring='f1')                   
    f1_scores[i] = scores['test_score']
# Out:
# 10
# 20
# 30
# 40
# 50

# %%
fig = plt.figure(figsize=(11,5))

means = np.mean(f1_scores,axis=1)
stds = np.std(f1_scores,axis=1)
x = np.arange(0,len(N_features))
plt.errorbar(x,means,yerr=stds,marker='o',capsize=5,lw=3,mec='k',ms=10)
x_tick_locs = np.arange(0,len(N_features))

plt.xticks(x_tick_locs,["%d" %N for N in N_features])    

plt.xlabel("Number of Features Used")
plt.ylabel(r'$F_1$ score')
# Out:
# Text(0, 0.5, '$F_1$ score')

# %%
clf.tree_.max_depth
# Out:
# 74

# %% [markdown]
# ### Now we grid search

# %%
games_added = 5.889 - 1 #Avg missed games from missed_games notebook - 1 because the player is rested in that game

def net_games(estimator, X, y_true):
    predicted = estimator.predict(X)
    cm = metrics.confusion_matrix(y_true,predicted)
    return games_added*cm[1,1]-cm[0,1]

# %%
X_train, X_test, y_train, y_test = train_test_split(X[sort_df[0][:50]], y, test_size=0.25)

# %%
params = [{'class_weight' : [{0:1,1:1},{0:1,1:3},{0:1,1:5},{0:1,1:10},{0:1,1:15},{0:1,1:20}\
                    ,],'max_depth' : [None,100,50,30,20,15,10,5], 'min_samples_split' : [2,5,10,20,30,50,75]}]
       
model=DecisionTreeClassifier()

clf = model_selection.GridSearchCV(model,params,scoring=net_games,verbose=3,n_jobs=6)

clf.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 336 candidates, totalling 1680 fits
# [Parallel(n_jobs=6)]: Using backend LokyBackend with 6 concurrent workers.
# [Parallel(n_jobs=6)]: Done  20 tasks      | elapsed:   31.8s
# [Parallel(n_jobs=6)]: Done 116 tasks      | elapsed:  3.2min
# [Parallel(n_jobs=6)]: Done 276 tasks      | elapsed:  5.8min
# [Parallel(n_jobs=6)]: Done 500 tasks      | elapsed: 10.7min
# [Parallel(n_jobs=6)]: Done 788 tasks      | elapsed: 15.2min
# [Parallel(n_jobs=6)]: Done 1140 tasks      | elapsed: 20.2min
# [Parallel(n_jobs=6)]: Done 1556 tasks      | elapsed: 26.7min
# [Parallel(n_jobs=6)]: Done 1680 out of 1680 | elapsed: 28.2min finished
# GridSearchCV(estimator=DecisionTreeClassifier(), n_jobs=6,
#              param_grid=[{'class_weight': [{0: 1, 1: 1}, {0: 1, 1: 3},
#                                            {0: 1, 1: 5}, {0: 1, 1: 10},
#                                            {0: 1, 1: 15}, {0: 1, 1: 20}],
#                           'max_depth': [None, 100, 50, 30, 20, 15, 10, 5],
#                           'min_samples_split': [2, 5, 10, 20, 30, 50, 75]}],
#              scoring=<function net_games at 0x13397b9d8>, verbose=3)

# %%
X_train
# Out:
#               Age   +/-_Av21    +/-_Av7  FG_per_Av21  Avg_Speed_Off_Av_7  \
# 122849  22.186174  -0.888889  -1.000000     0.416667                4.47
# 45083   21.235455   4.250000   5.000000     0.333333                4.53
# 105654  24.936345 -11.250000  -6.666667     0.216216                4.82
# 62310   25.766598   1.555556  -3.000000     0.475862                4.07
# 76308   20.355921  -2.000000  -7.250000     0.503876                4.47
# 7597    29.199863   4.666667   2.000000     0.402597                4.46
# 80101           6.0  2.222222   0.666667                 0.67
# 29950           4.0  0.000000   2.000000                 1.10
# 122641          7.0  1.500000   2.666667                 1.28
# 107899         10.0  0.500000   1.333333                 1.18
# 60954           4.0  0.111111   0.000000                 0.48
# 68315           1.0  0.555556   0.333333                 0.92
# 76781           6.0  0.777778   0.000000                 0.74
# 14316           7.0  0.500000   3.000000                 0.53
# 117452         12.0  2.222222   3.000000                 1.09
# 39721           6.0  0.666667   6.666667                 1.38
# 22176           4.0  0.200000   4.333333                 1.38
# 20124           0.0  2.363636   2.000000                 0.69
# 114347          6.0  0.555556   1.000000                 1.17
# 130668         21.0  0.250000   0.666667                 0.97
# 43013           2.0  0.333333   1.000000                 0.82
# 131587         10.0  0.636364   1.250000                 1.08
# 13759           5.0  1.750000   2.000000                 0.93
# 59913          22.0  0.000000   1.333333                 0.76
# 95174           1.0  1.750000   2.333333                 0.49
# 72960           9.0  0.454545   7.333333                 1.10
# 57104           3.0  0.625000   4.000000                 1.27
# 23660           2.0  0.200000   0.250000                 0.89
# 130299          5.0  1.000000   2.500000                 1.45
# 80506           1.0  0.600000   2.000000                 0.12
# 39510          12.0  3.000000   2.500000                 1.07
# 36775           7.0  3.000000  17.000000                 0.93
# 42670           2.0  0.375000   1.500000                 1.04
# 116226          5.0  4.666667   6.500000                 1.03
# 69353          13.0  1.818182   4.000000                 1.17
#
#         Dist_Miles_Off_Av_14
# 122849                  0.63
# 45083                   0.45
# 105654                  0.91
# 62310                   1.21
# 76308                   1.05
# 7597                    0.88
# 108476                  0.94
# 131566                  0.97
# 15149                   1.24
# 22879                   0.78
# 39575                   0.69
# 80486                   0.70
# 53738                   1.23
# 83536                   1.09
# 80900                   1.20
# 33647                   1.09
# 68475                   1.19
# 132548                  1.55
# 29556                   0.95
# 57965                   1.22
# 70922                   1.42
# 25211                   0.84
# 52527                   0.87
# 27407                   1.17
# 122583                  0.86
# 77258                   0.99
# 96283                   1.10
# 93649                   0.95
# 69424                   1.39
# 110005                  0.45
# ...                      ...
# 105567                  1.24
# 80101                   0.82
# 29950                   1.10
# 122641                  1.02
# 107899                  1.09
# 60954                   0.49
# 68315                   0.88
# 76781                   0.97
# 14316                   0.53
# 117452                  1.01
# 39721                   1.29
# 22176                   1.32
# 20124                   0.70
# 114347                  1.19
# 130668                  0.96
# 43013                   0.63
# 131587                  1.05
# 13759                   0.92
# 59913                   0.76
# 95174                   0.58
# 72960                   1.18
# 57104                   1.30
# 23660                   0.90
# 130299                  1.31
# 80506                   0.12
# 39510                   1.11
# 36775                   0.93
# 42670                   1.10
# 116226                  0.98
# 69353                   1.31
#
# [99804 rows x 30 columns]

# %%
print(clf.best_score_,clf.best_params_)
# Out:
# -3.2 {'class_weight': {0: 1, 1: 1}, 'max_depth': 5, 'min_samples_split': 75}

# %%
clf.predict()
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0
# 8        {0: 1, 1: 1}              30                      20
# 9        {0: 1, 1: 1}              15                       2
# 10       {0: 1, 1: 1}              15                       5
# 11       {0: 1, 1: 1}              15                      20
# 12       {0: 1, 1: 3}            None                       2
# 13       {0: 1, 1: 3}            None                       5
# 14       {0: 1, 1: 3}            None                      20
# 15       {0: 1, 1: 3}              50                       2
# 16       {0: 1, 1: 3}              50                       5
# 17       {0: 1, 1: 3}              50                      20
# 18       {0: 1, 1: 3}              30                       2
# 19       {0: 1, 1: 3}              30                       5
# 20       {0: 1, 1: 3}              30                      20
# 21       {0: 1, 1: 3}              15                       2
# 22       {0: 1, 1: 3}              15                       5
# 23       {0: 1, 1: 3}              15                      20
# 24       {0: 1, 1: 5}            None                       2
# 25       {0: 1, 1: 5}            None                       5
# 26       {0: 1, 1: 5}            None                      20
# 27       {0: 1, 1: 5}              50                       2
# 28       {0: 1, 1: 5}              50                       5
# 29       {0: 1, 1: 5}              50                      20
# ..                ...             ...                     ...
# 66      {0: 1, 1: 20}              30                       2
# 67      {0: 1, 1: 20}              30                       5
# 68      {0: 1, 1: 20}              30                      20
# 69      {0: 1, 1: 20}              15                       2
# 70      {0: 1, 1: 20}              15                       5
# 71      {0: 1, 1: 20}              15                      20
# 72      {0: 1, 1: 30}            None                       2
# 73      {0: 1, 1: 30}            None                       5
# 74      {0: 1, 1: 30}            None                      20
# 75      {0: 1, 1: 30}              50                       2
# 76      {0: 1, 1: 30}              50                       5
# 77      {0: 1, 1: 30}              50                      20
# 78      {0: 1, 1: 30}              30                       2
# 79      {0: 1, 1: 30}              30                       5
# 80      {0: 1, 1: 30}              30                      20
# 81      {0: 1, 1: 30}              15                       2
# 82      {0: 1, 1: 30}              15                       5
# 83      {0: 1, 1: 30}              15                      20
# 84      {0: 1, 1: 40}            None                       2
# 85      {0: 1, 1: 40}            None                       5
# 86      {0: 1, 1: 40}            None                      20
# 87      {0: 1, 1: 40}              50                       2
# 88      {0: 1, 1: 40}              50                       5
# 89      {0: 1, 1: 40}              50                      20
# 90      {0: 1, 1: 40}              30                       2
# 91      {0: 1, 1: 40}              30                       5
# 92      {0: 1, 1: 40}              30                      20
# 93      {0: 1, 1: 40}              15                       2
# 94      {0: 1, 1: 40}              15                       5
# 95      {0: 1, 1: 40}              15                      20
#
#                                                params  split0_test_score  \
# 0   {'class_weight': {0: 1, 1: 1}, 'max_depth': No...           -599.774
# 1   {'class_weight': {0: 1, 1: 1}, 'max_depth': No...           -501.774
# 2   {'class_weight': {0: 1, 1: 1}, 'max_depth': No...           -288.665
# 3   {'class_weight': {0: 1, 1: 1}, 'max_depth': 50...           -617.219
# 4   {'class_weight': {0: 1, 1: 1}, 'max_depth': 50...           -504.441
# 5   {'class_weight': {0: 1, 1: 1}, 'max_depth': 50...           -282.665
# 6   {'class_weight': {0: 1, 1: 1}, 'max_depth': 30...           -368.886
# 7   {'class_weight': {0: 1, 1: 1}, 'max_depth': 30...           -327.664
# 8   {'class_weight': {0: 1, 1: 1}, 'max_depth': 30...           -223.332
# 9   {'class_weight': {0: 1, 1: 1}, 'max_depth': 15...            -74.777
# 10  {'class_weight': {0: 1, 1: 1}, 'max_depth': 15...            -58.110
# 11  {'class_weight': {0: 1, 1: 1}, 'max_depth': 15...            -58.555
# 12  {'class_weight': {0: 1, 1: 3}, 'max_depth': No...           -504.996
# 13  {'class_weight': {0: 1, 1: 3}, 'max_depth': No...           -552.329
# 14  {'class_weight': {0: 1, 1: 3}, 'max_depth': No...           -745.662
# 15  {'class_weight': {0: 1, 1: 3}, 'max_depth': 50...           -502.218
# 16  {'class_weight': {0: 1, 1: 3}, 'max_depth': 50...           -583.996
# 17  {'class_weight': {0: 1, 1: 3}, 'max_depth': 50...           -718.884
# 18  {'class_weight': {0: 1, 1: 3}, 'max_depth': 30...           -428.552
# 19  {'class_weight': {0: 1, 1: 3}, 'max_depth': 30...           -464.663
# 20  {'class_weight': {0: 1, 1: 3}, 'max_depth': 30...           -631.107
# 21  {'class_weight': {0: 1, 1: 3}, 'max_depth': 15...           -200.776
# 22  {'class_weight': {0: 1, 1: 3}, 'max_depth': 15...           -222.332
# 23  {'class_weight': {0: 1, 1: 3}, 'max_depth': 15...           -251.887
# 24  {'class_weight': {0: 1, 1: 5}, 'max_depth': No...           -460.330
# 25  {'class_weight': {0: 1, 1: 5}, 'max_depth': No...           -577.774
# 26  {'class_weight': {0: 1, 1: 5}, 'max_depth': No...          -1083.328
# 27  {'class_weight': {0: 1, 1: 5}, 'max_depth': 50...           -526.997
# 28  {'class_weight': {0: 1, 1: 5}, 'max_depth': 50...           -614.552
# 29  {'class_weight': {0: 1, 1: 5}, 'max_depth': 50...          -1067.328
# ..                                                ...                ...
# 66  {'class_weight': {0: 1, 1: 20}, 'max_depth': 3...           -810.329
# 67  {'class_weight': {0: 1, 1: 20}, 'max_depth': 3...           -876.329
# 68  {'class_weight': {0: 1, 1: 20}, 'max_depth': 3...          -1317.549
# 69  {'class_weight': {0: 1, 1: 20}, 'max_depth': 1...          -1804.099
# 70  {'class_weight': {0: 1, 1: 20}, 'max_depth': 1...          -1824.099
# 71  {'class_weight': {0: 1, 1: 20}, 'max_depth': 1...          -1969.432
# 72  {'class_weight': {0: 1, 1: 30}, 'max_depth': N...           -536.775
# 73  {'class_weight': {0: 1, 1: 30}, 'max_depth': N...           -611.775
# 74  {'class_weight': {0: 1, 1: 30}, 'max_depth': N...          -1122.773
# 75  {'class_weight': {0: 1, 1: 30}, 'max_depth': 5...           -549.552
# 76  {'class_weight': {0: 1, 1: 30}, 'max_depth': 5...           -584.774
# 77  {'class_weight': {0: 1, 1: 30}, 'max_depth': 5...          -1116.439
# 78  {'class_weight': {0: 1, 1: 30}, 'max_depth': 3...          -1166.773
# 79  {'class_weight': {0: 1, 1: 30}, 'max_depth': 3...          -1198.106
# 80  {'class_weight': {0: 1, 1: 30}, 'max_depth': 3...          -1597.216
# 81  {'class_weight': {0: 1, 1: 30}, 'max_depth': 1...          -4069.869
# 82  {'class_weight': {0: 1, 1: 30}, 'max_depth': 1...          -4064.869
# 83  {'class_weight': {0: 1, 1: 30}, 'max_depth': 1...          -4170.424
# 84  {'class_weight': {0: 1, 1: 40}, 'max_depth': N...           -455.553
# 85  {'class_weight': {0: 1, 1: 40}, 'max_depth': N...           -513.108
# 86  {'class_weight': {0: 1, 1: 40}, 'max_depth': N...          -1062.107
# 87  {'class_weight': {0: 1, 1: 40}, 'max_depth': 5...           -508.441
# 88  {'class_weight': {0: 1, 1: 40}, 'max_depth': 5...           -568.552
# 89  {'class_weight': {0: 1, 1: 40}, 'max_depth': 5...          -1085.217
# 90  {'class_weight': {0: 1, 1: 40}, 'max_depth': 3...          -1290.993
# 91  {'class_weight': {0: 1, 1: 40}, 'max_depth': 3...          -1282.770
# 92  {'class_weight': {0: 1, 1: 40}, 'max_depth': 3...          -1642.214
# 93  {'class_weight': {0: 1, 1: 40}, 'max_depth': 1...          -4316.198
# 94  {'class_weight': {0: 1, 1: 40}, 'max_depth': 1...          -4328.198
# 95  {'class_weight': {0: 1, 1: 40}, 'max_depth': 1...          -4411.531
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            -599.663           -548.774           -624.219
# 1            -449.440           -489.664           -521.553
# 2            -220.998           -254.443           -261.776
# 3            -596.663           -564.664           -606.997
# 4            -465.663           -505.331           -499.664
# 5            -224.220           -240.443           -278.332
# 6            -399.108           -362.109           -400.331
# 7            -361.108           -279.220           -332.220
# 8            -186.665           -169.999           -179.554
# 9             -64.221            -58.222            -75.110
# 10            -56.554            -68.333            -78.888
# 11            -30.999            -24.444            -43.777
# 12           -527.441           -570.220           -589.886
# 13           -558.884           -585.330           -607.440
# 14           -724.328           -778.663           -796.328
# 15           -502.885           -501.886           -572.441
# 16           -567.440           -599.664           -644.218
# 17           -703.550           -762.885           -813.328
# 18           -449.330           -411.553           -513.108
# 19           -465.996           -454.886           -592.885
# 20           -629.439           -606.663           -729.106
# 21           -125.331           -186.332           -275.332
# 22           -146.220           -202.221           -288.221
# 23           -233.886           -246.887           -351.331
# 24           -528.997           -517.885           -548.997
# 25           -630.330           -658.663           -636.774
# 26          -1048.105          -1075.327          -1028.993
# 27           -526.219           -546.552           -526.219
# 28           -633.997           -644.107           -696.219
# 29          -1058.994          -1078.327          -1037.660
# ..                ...                ...                ...
# 66           -569.884           -679.663           -656.219
# 67           -633.995           -715.663           -712.552
# 68          -1190.326          -1196.994          -1231.439
# 69          -2465.099          -1856.434          -2265.211
# 70          -2482.988          -1852.878          -2273.544
# 71          -2656.876          -2035.877          -2465.544
# 72           -494.441           -477.219           -499.331
# 73           -532.996           -500.774           -520.330
# 74          -1060.771          -1081.884          -1016.328
# 75           -460.329           -548.664           -525.220
# 76           -555.107           -557.552           -573.108
# 77          -1032.771          -1135.106          -1038.995
# 78           -875.438           -933.217           -930.661
# 79           -913.327           -931.883           -918.660
# 80          -1310.992          -1317.326          -1346.548
# 81          -3537.757          -3083.652          -4222.758
# 82          -3541.757          -3107.430          -4242.869
# 83          -3672.201          -3212.318          -4364.758
# 84           -462.886           -525.442           -455.108
# 85           -499.775           -534.886           -539.663
# 86          -1057.884           -998.439           -989.772
# 87           -569.553           -587.775           -585.329
# 88           -610.219           -612.552           -633.996
# 89          -1053.550          -1086.106          -1058.327
# 90          -1184.660          -1523.770          -1321.992
# 91          -1216.993          -1574.214          -1338.881
# 92          -1557.659          -1871.213          -1644.991
# 93          -4479.089          -5039.086          -5840.530
# 94          -4514.756          -5059.864          -5830.752
# 95          -4624.756          -5123.864          -5933.863
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0
# 95          -5747.970       -5168.3968      598.701583               96
#
# [96 rows x 16 columns]

# %%
print(clf.best_params_,clf.best_score_)
# Out:
# {'class_weight': {0: 1, 1: 1}, 'max_depth': 15, 'min_samples_split': 20} -36.177

# %%
predicted = clf.predict(X_test)

# %%
print(metrics.accuracy_score(y_test, predicted))
print(metrics.classification_report(y_test, predicted))

cm = metrics.confusion_matrix(y_test,predicted)
print(cm)

print(metrics.f1_score(y_test, predicted))
# Out:
# 0.9705122039196826
#               precision    recall  f1-score   support
#
#          0.0       0.97      1.00      0.99     32288
#          1.0       0.00      0.00      0.00       980
#
#     accuracy                           0.97     33268
#    macro avg       0.49      0.50      0.49     33268
# weighted avg       0.94      0.97      0.96     33268
#
# [[32287     1]
#  [  980     0]]
# 0.0

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
y = injs['Was_Injured']
X = injs.drop(columns=['Was_Injured','Dist_Feet_Av_7','Dist_Feet_Av_14','Dist_Feet_Av_21','Date','Name'])

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)

clf = RandomForestClassifier(n_jobs=-1,verbose=True)
clf.fit(X_train,y_train)
# Out:
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:    3.9s
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:   11.4s finished
# RandomForestClassifier(n_jobs=-1, verbose=True)

# %%
predicted = clf.predict(X_test)
# Out:
# [Parallel(n_jobs=12)]: Using backend ThreadingBackend with 12 concurrent workers.
# [Parallel(n_jobs=12)]: Done  26 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=12)]: Done 100 out of 100 | elapsed:    0.1s finished

# %%
print(metrics.accuracy_score(y_test, predicted))
print(metrics.classification_report(y_test, predicted))

cm = metrics.confusion_matrix(y_test,predicted)
print(cm)

print(metrics.f1_score(y_test, predicted))
# Out:
# 0.970271732595888
#               precision    recall  f1-score   support
#
#          0.0       0.97      1.00      0.98     32280
#          1.0       0.00      0.00      0.00       988
#
#     accuracy                           0.97     33268
#    macro avg       0.49      0.50      0.49     33268
# weighted avg       0.94      0.97      0.96     33268
#
# [[32279     1]
#  [  988     0]]
# 0.0

# %%
coeffs = pd.DataFrame(zip(X.columns, np.transpose(clf.feature_importances_)))
sort_df = coeffs.loc[coeffs[1].abs().argsort()[::-1]].reset_index(drop=True)

# %%
sort_df
# Out:
#                                                      0         1
# 0                                                  Age  0.017185
# 1                                              +/-_Av7  0.014608
# 2                                             +/-_Av14  0.014119
# 3                                             +/-_Av21  0.013626
# 4                                  Avg_Speed_Off_Av_14  0.012789
# 5                                              MP_Av21  0.012555
# 6                                              PF_Av21  0.012519
# 7                                          FG_per_Av21  0.012386
# 8                                  Avg_Speed_Off_Av_21  0.012336
# 9                                         ann_inj_rate  0.012310
# 10                                  Avg_Speed_Off_Av_7  0.012217
# 11                                            GmSc_Av7  0.012178
# 12                                         FG_per_Av14  0.012050
# 13                                              MP_Av7  0.012039
# 14                                           GmSc_Av14  0.011987
# 15                                           GmSc_Av21  0.011804
# 16                                      Avg_Speed_Av_7  0.011758
# 17                                         N_prev_injs  0.011688
# 18                                             MP_Av14  0.011687
# 19                                 Avg_Speed_Def_Av_14  0.011655
# 20                                  Avg_Speed_Def_Av_7  0.011598
# 21                                            AST_Av21  0.011509
# 22                                 Avg_Speed_Def_Av_21  0.011497
# 23                                            FGA_Av21  0.011408
# 24                                     Avg_Speed_Av_21  0.011189
# 25                                          FG_per_Av7  0.011145
# 26                                            TOV_Av21  0.011132
# 27                                     Avg_Speed_Av_14  0.011027
# 28                                            AST_Av14  0.010976
# 29                                            STL_Av21  0.010956
# ..                                                 ...       ...
# 108                                         FT_per_b2b  0.001391
# 109                                               Wing  0.001370
# 110                                            TOV_b2b  0.001366
# 111                   Small_Forward_and_Shooting_Guard  0.001350
# 112                                            FTA_b2b  0.001336
# 113                     Point_Guard_and_Shooting_Guard  0.001294
# 114                                         3P_per_b2b  0.001290
# 115                                            BLK_b2b  0.001266
# 116                    Power_Forward_and_Small_Forward  0.001257
# 117                                            ORB_b2b  0.001221
# 118                                      Power_Forward  0.001196
# 119                                             FT_b2b  0.001156
# 120                                            STL_b2b  0.001152
# 121                                             3P_b2b  0.001130
# 122                                     Shooting_Guard  0.001117
# 123                                              Right  0.001079
# 124                                               Left  0.001070
# 125                                              Guard  0.001006
# 126                           Center_and_Power_Forward  0.000932
# 127  Power_Forward_and_Small_Forward_and_Shooting_G...  0.000877
# 128                                                Big  0.000872
# 129                                             Center  0.000855
# 130                                        Point_Guard  0.000709
# 131   Point_Guard_and_Small_Forward_and_Shooting_Guard  0.000588
# 132                                                b2b  0.000515
# 133         Center_and_Power_Forward_and_Small_Forward  0.000443
# 134                                         Left_Right  0.000232
# 135  Power_Forward_and_Point_Guard_and_Small_Forwar...  0.000128
# 136                   Power_Forward_and_Shooting_Guard  0.000089
# 137                      Point_Guard_and_Small_Forward  0.000030
#
# [138 rows x 2 columns]

# %% [markdown]
# ### Now we grid search

# %%
games_added = 5.889 - 1 #Avg missed games from missed_games notebook - 1 because the player is rested in that game

def net_games(estimator, X, y_true):
    predicted = estimator.predict(X)
    cm = metrics.confusion_matrix(y_true,predicted)
    return games_added*cm[1,1]-cm[0,1]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)

# %%
params = [{'max_depth' : [None,50,30,20,15,10,5], 'min_samples_split' : [2,5,10,20,30,50]}]
       
model = RandomForestClassifier(class_weight = {0:1,1:games_added},n_jobs=6)

clf = model_selection.GridSearchCV(model,params,scoring=net_games,verbose=3,n_jobs=6)

clf.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 42 candidates, totalling 210 fits
# [Parallel(n_jobs=6)]: Using backend LokyBackend with 6 concurrent workers.
# [Parallel(n_jobs=6)]: Done  20 tasks      | elapsed:  4.5min
# [Parallel(n_jobs=6)]: Done 116 tasks      | elapsed: 22.1min
# [Parallel(n_jobs=6)]: Done 210 out of 210 | elapsed: 30.6min finished
# GridSearchCV(estimator=RandomForestClassifier(class_weight={0: 1, 1: 4.889},
#                                               n_jobs=6),
#              n_jobs=6,
#              param_grid=[{'max_depth': [None, 50, 30, 20, 15, 10, 5],
#                           'min_samples_split': [2, 5, 10, 20, 30, 50]}],
#              scoring=<function net_games at 0x127b73f28>, verbose=3)

# %%
clf.best_score_
# Out:
# 0.9778

# %%
clf.best_params_
# Out:
# {'max_depth': 30, 'min_samples_split': 10}

# %%
X_train, X_test, y_train, y_test = train_test_split(X[sort_df[0][:50]], y, test_size=0.25)

clf = RandomForestClassifier(class_weight = 'balanced',n_jobs=-1)
clf.fit(X_train,y_train)
# Out:
# RandomForestClassifier(class_weight='balanced', n_jobs=-1)

# %%
predicted = clf.predict(X_test)

# %%
print(metrics.accuracy_score(y_test, predicted))
print(metrics.classification_report(y_test, predicted))

cm = metrics.confusion_matrix(y_test,predicted)
print(cm)

print(metrics.f1_score(y_test, predicted))
# Out:
# 0.9715642659612841
#               precision    recall  f1-score   support
#
#          0.0       0.97      1.00      0.99     32322
#          1.0       0.00      0.00      0.00       946
#
#     accuracy                           0.97     33268
#    macro avg       0.49      0.50      0.49     33268
# weighted avg       0.94      0.97      0.96     33268
#
# [[32322     0]
#  [  946     0]]
# 0.0
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
clf.best_params_

# %% [markdown]
# ## SVM

# %%
from sklearn.svm import SVC

# %%
y = injs['Was_Injured']
X = injs[['Age', 'MP_Av14', '3P_Av14', '3PA_Av14', 'FTA_Av14', 'DRB_Av14',
       'MP_Av21', 'FTA_Av21', 'FT_per_Av21', 'DRB_Av21', 'FTA_b2b',
       'FT_per_b2b', 'N_prev_injs', 'W_Av_7', 'L_Av_7', 'Dist_Miles_Off_Av_7',
       'W_Av_14', 'L_Av_14', 'Dist_Miles_Def_Av_14', 'Avg_Speed_Off_Av_14',
       'L_Av_21', 'Dist_Miles_Av_21', 'Dist_Miles_Def_Av_21',
       'Avg_Speed_Off_Av_21']]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5)
scaler = sklearn.preprocessing.StandardScaler().fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

clf = SVC(verbose=True,kernel='rbf')
clf.fit(X_train,y_train)
# Out:
# [LibSVM]
# SVC(verbose=True)

# %%
predicted = clf.predict(X_test)

# %%
print(metrics.accuracy_score(y_test, predicted))
print(metrics.classification_report(y_test, predicted))

cm = metrics.confusion_matrix(y_test,predicted)
print(cm)

print(metrics.f1_score(y_test, predicted))
# Out:
# 0.9698358783215102
#               precision    recall  f1-score   support
#
#          0.0       0.97      1.00      0.98     64529
#          1.0       0.00      0.00      0.00      2007
#
#     accuracy                           0.97     66536
#    macro avg       0.48      0.50      0.49     66536
# weighted avg       0.94      0.97      0.95     66536
#
# [[64529     0]
#  [ 2007     0]]
# 0.0
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ### Try with moderate class weight

# %%
games_added = 5.889 - 1

y = injs['Was_Injured']
X = injs[['Age', 'MP_Av14', '3P_Av14', '3PA_Av14', 'FTA_Av14', 'DRB_Av14',
       'MP_Av21', 'FTA_Av21', 'FT_per_Av21', 'DRB_Av21', 'FTA_b2b',
       'FT_per_b2b', 'N_prev_injs', 'W_Av_7', 'L_Av_7', 'Dist_Miles_Off_Av_7',
       'W_Av_14', 'L_Av_14', 'Dist_Miles_Def_Av_14', 'Avg_Speed_Off_Av_14',
       'L_Av_21', 'Dist_Miles_Av_21', 'Dist_Miles_Def_Av_21',
       'Avg_Speed_Off_Av_21']]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)
scaler = sklearn.preprocessing.StandardScaler().fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

clf = SVC(verbose=True,kernel='rbf',class_weight={0:1,1:games_added})
clf.fit(X_train,y_train)
# Out:
# [LibSVM]
# SVC(class_weight={0: 1, 1: 4.889}, verbose=True)

# %%
predicted = clf.predict(X_test)

# %%
print(metrics.accuracy_score(y_test, predicted))
print(metrics.classification_report(y_test, predicted))

cm = metrics.confusion_matrix(y_test,predicted)
print(cm)

print(metrics.f1_score(y_test, predicted))
# Out:
# 0.9697607310328243
#               precision    recall  f1-score   support
#
#          0.0       0.97      1.00      0.98     32264
#          1.0       0.00      0.00      0.00      1004
#
#     accuracy                           0.97     33268
#    macro avg       0.48      0.50      0.49     33268
# weighted avg       0.94      0.97      0.95     33268
#
# [[32262     2]
#  [ 1004     0]]
# 0.0

# %% [markdown]
# ### Try with balanced class weight

# %%
games_added = 5.889 - 1

y = injs['Was_Injured']
X = injs[['Age', 'MP_Av14', '3P_Av14', '3PA_Av14', 'FTA_Av14', 'DRB_Av14',
       'MP_Av21', 'FTA_Av21', 'FT_per_Av21', 'DRB_Av21', 'FTA_b2b',
       'FT_per_b2b', 'N_prev_injs', 'W_Av_7', 'L_Av_7', 'Dist_Miles_Off_Av_7',
       'W_Av_14', 'L_Av_14', 'Dist_Miles_Def_Av_14', 'Avg_Speed_Off_Av_14',
       'L_Av_21', 'Dist_Miles_Av_21', 'Dist_Miles_Def_Av_21',
       'Avg_Speed_Off_Av_21']]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)
scaler = sklearn.preprocessing.StandardScaler().fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

clf = SVC(verbose=True,kernel='rbf',class_weight='balanced')
clf.fit(X_train,y_train)
# Out:
# [LibSVM]
# SVC(class_weight='balanced', verbose=True)

# %%
predicted = clf.predict(X_test)

# %%
print(metrics.accuracy_score(y_test, predicted))
print(metrics.classification_report(y_test, predicted))

cm = metrics.confusion_matrix(y_test,predicted)
print(cm)

print(metrics.f1_score(y_test, predicted))
# Out:
# 0.6855837441385115
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.69      0.81     32306
#          1.0       0.04      0.46      0.08       962
#
#     accuracy                           0.69     33268
#    macro avg       0.51      0.58      0.44     33268
# weighted avg       0.95      0.69      0.79     33268
#
# [[22366  9940]
#  [  520   442]]
# 0.07792665726375177

# %% [markdown]
# ### Try with balanced class weight

# %%
games_added = 5.889 - 1

y = injs['Was_Injured']
X = injs[['Age', 'MP_Av14', '3P_Av14', '3PA_Av14', 'FTA_Av14', 'DRB_Av14',
       'MP_Av21', 'FTA_Av21', 'FT_per_Av21', 'DRB_Av21', 'FTA_b2b',
       'FT_per_b2b', 'N_prev_injs', 'W_Av_7', 'L_Av_7', 'Dist_Miles_Off_Av_7',
       'W_Av_14', 'L_Av_14', 'Dist_Miles_Def_Av_14', 'Avg_Speed_Off_Av_14',
       'L_Av_21', 'Dist_Miles_Av_21', 'Dist_Miles_Def_Av_21',
       'Avg_Speed_Off_Av_21']]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)
scaler = sklearn.preprocessing.StandardScaler().fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

clf = SVC(verbose=True,kernel='rbf',class_weight='balanced',C=1e3)
clf.fit(X_train,y_train)
# Out:
# [LibSVM]
# SVC(C=1000.0, class_weight='balanced', verbose=True)

# %%
predicted = clf.predict(X_test)

# %%
print(metrics.accuracy_score(y_test, predicted))
print(metrics.classification_report(y_test, predicted))

cm = metrics.confusion_matrix(y_test,predicted)
print(cm)

print(metrics.f1_score(y_test, predicted))
# Out:
# 0.915203799446916
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.94      0.96     32292
#          1.0       0.04      0.07      0.05       976
#
#     accuracy                           0.92     33268
#    macro avg       0.50      0.51      0.50     33268
# weighted avg       0.94      0.92      0.93     33268
#
# [[30375  1917]
#  [  904    72]]
# 0.04856661045531197
