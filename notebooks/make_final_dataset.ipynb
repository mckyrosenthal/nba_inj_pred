# %%
import pandas as pd
import numpy as np
import datetime

def str2datetime(date):
    
    date_tmp = date.split('-')
    
    y = int(date_tmp[0])
    m = int(date_tmp[1])
    d = int(date_tmp[2])
    
    return datetime.datetime(y,m,d)

# %% [markdown]
# ### Load in and combine speed and distance tracking data

# %%
speed_dist_7 = pd.read_csv('speed_dist_7days.csv')
speed_dist_7.drop(columns=['Unnamed: 0','GP','Min'],inplace=True)

speed_dist_14 = pd.read_csv('speed_dist_14days.csv')
speed_dist_14.drop(columns=['Unnamed: 0','Team','GP','Min'],inplace=True)

speed_dist_21 = pd.read_csv('speed_dist_21days.csv')
speed_dist_21.drop(columns=['Unnamed: 0','Team','GP','Min'],inplace=True)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3049: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
col_dict_7 = {}
col_dict_14 = {}
col_dict_21 = {}

for c in speed_dist_7.columns[3:]:
    col_dict_7[c] = c+'_Av_7'
    col_dict_14[c] = c+'_Av_14'
    col_dict_21[c] = c+'_Av_21'

# %%
speed_dist_7.rename(columns=col_dict_7,inplace=True)
speed_dist_14.rename(columns=col_dict_14,inplace=True)
speed_dist_21.rename(columns=col_dict_21,inplace=True)

# %%
same_cols = ['Date','Name']

tmp = speed_dist_7.merge(speed_dist_14,how='inner',left_on=same_cols,right_on=same_cols)
speed_dist_full = tmp.merge(speed_dist_21,how='inner',left_on=same_cols,right_on=same_cols)
speed_dist_full.drop_duplicates(subset=['Name','Date'],inplace=True)

# %% [markdown]
# ### Load in data with all windows

# %%
full_df = pd.read_csv('inj_all_windows.csv')
full_df = full_df.drop(columns='Unnamed: 0')
full_df = full_df.sort_values(by=['Name','Date']).reset_index(drop=True)

# %%
for c in full_df.columns:
    print(c)
# Out:
# Name
# Height [cm]
# Weight [kg]
# Position
# Pos3
# Shoots
# Date
# Age
# Opp
# MP
# FG
# FGA
# FG%
# 3P
# 3PA
# 3P%
# FT
# FTA
# FT%
# ORB
# DRB
# TRB
# AST
# STL
# BLK
# TOV
# PF
# PTS
# GmSc
# +/-
# Was_Injured?
# Notes
# MP_Av7
# FG_Av7
# FGA_Av7
# FG%_Av7
# 3P_Av7
# 3PA_Av7
# 3P%_Av7
# FT_Av7
# FTA_Av7
# FT%_Av7
# ORB_Av7
# DRB_Av7
# TRB_Av7
# AST_Av7
# STL_Av7
# BLK_Av7
# TOV_Av7
# PF_Av7
# PTS_Av7
# GmSc_Av7
# +/-_Av7
# N_games_7
# MP_Av14
# FG_Av14
# FGA_Av14
# FG%_Av14
# 3P_Av14
# 3PA_Av14
# 3P%_Av14
# FT_Av14
# FTA_Av14
# FT%_Av14
# ORB_Av14
# DRB_Av14
# TRB_Av14
# AST_Av14
# STL_Av14
# BLK_Av14
# TOV_Av14
# PF_Av14
# PTS_Av14
# GmSc_Av14
# +/-_Av14
# N_games_14
# MP_Av21
# FG_Av21
# FGA_Av21
# FG%_Av21
# 3P_Av21
# 3PA_Av21
# 3P%_Av21
# FT_Av21
# FTA_Av21
# FT%_Av21
# ORB_Av21
# DRB_Av21
# TRB_Av21
# AST_Av21
# STL_Av21
# BLK_Av21
# TOV_Av21
# PF_Av21
# PTS_Av21
# GmSc_Av21
# +/-_Av21
# N_games_21
# MP_b2b
# FG_b2b
# FGA_b2b
# FG%_b2b
# 3P_b2b
# 3PA_b2b
# 3P%_b2b
# FT_b2b
# FTA_b2b
# FT%_b2b
# ORB_b2b
# DRB_b2b
# TRB_b2b
# AST_b2b
# STL_b2b
# BLK_b2b
# TOV_b2b
# PF_b2b
# PTS_b2b
# GmSc_b2b
# +/-_b2b
# b2b

# %% [markdown]
# ### Add in column tracking number of previous injuries a player had

# %%
N_rows = full_df.shape[0]
N_inj_arr = np.zeros(N_rows)

name = ""
N_injs = 0

for i in range(N_rows):
    
    r = full_df.iloc[i-1] #Look at the previous row, as we want to be careful to not use info from a game to decide
                          #whether or not a player got injured
    
    name_tmp = r['Name']
    
    if name_tmp == name:
        if r['Was_Injured?'] == 1:
            N_injs += 1
    else:
        N_injs = 0
        name = name_tmp
        
    N_inj_arr[i] = N_injs

# %%
full_df['N_prev_injs'] = N_inj_arr

# %%
full_df.loc[full_df['Was_Injured?']==1].iloc[:10]
# Out:
#                       Name  Height [cm]  Weight [kg]     Position   Pos3  \
# 58   (William) Tony Parker          188           83  Point Guard  Guard
# 120  (William) Tony Parker          188           83  Point Guard  Guard
# 125  (William) Tony Parker          188           83  Point Guard  Guard
# 207  (William) Tony Parker          188           83  Point Guard  Guard
# 211  (William) Tony Parker          188           83  Point Guard  Guard
# 213  (William) Tony Parker          188           83  Point Guard  Guard
# 219  (William) Tony Parker          188           83  Point Guard  Guard
# 220  (William) Tony Parker          188           83  Point Guard  Guard
# 222  (William) Tony Parker          188           83  Point Guard  Guard
# 259  (William) Tony Parker          188           83  Point Guard  Guard
#
#     Shoots        Date        Age  Opp         MP  ...  AST_b2b  STL_b2b  \
# 58   Right  2011-02-27  28.783025  MEM  13.933333  ...      NaN      NaN
# 120  Right  2012-03-07  29.807666  NYK  33.800000  ...      NaN      NaN
# 125  Right  2012-03-21  29.845996  MIN  10.483333  ...      NaN      NaN
# 207  Right  2013-02-10  30.736482  BRK  35.316667  ...      NaN      NaN
# 211  Right  2013-02-22  30.769336  GSW  40.483333  ...      7.0      1.0
# 213  Right  2013-03-01  30.788501  SAC  25.300000  ...      NaN      NaN
# 219  Right  2013-04-01  30.873374  MEM  33.300000  ...      8.0      0.0
# 220  Right  2013-04-04  30.881588  OKC  25.450000  ...      NaN      NaN
# 222  Right  2013-04-14  30.908966  LAL  28.283333  ...      NaN      NaN
# 259  Right  2013-11-27  31.531143  OKC  34.033333  ...      NaN      NaN
#
#      BLK_b2b  TOV_b2b  PF_b2b  PTS_b2b  GmSc_b2b  +/-_b2b  b2b  N_prev_injs
# 58       NaN      NaN     NaN      NaN       NaN      NaN  0.0          0.0
# 120      NaN      NaN     NaN      NaN       NaN      NaN  0.0          1.0
# 125      NaN      NaN     NaN      NaN       NaN      NaN  0.0          2.0
# 207      NaN      NaN     NaN      NaN       NaN      NaN  0.0          3.0
# 211      0.0      0.0     2.0     31.0      30.3     31.0  1.0          4.0
# 213      NaN      NaN     NaN      NaN       NaN      NaN  0.0          5.0
# 219      0.0      1.0     1.0     12.0       9.5     -9.0  1.0          6.0
# 220      NaN      NaN     NaN      NaN       NaN      NaN  0.0          7.0
# 222      NaN      NaN     NaN      NaN       NaN      NaN  0.0          8.0
# 259      NaN      NaN     NaN      NaN       NaN      NaN  0.0          9.0
#
# [10 rows x 121 columns]

# %% [markdown]
# ### Add in a column tracking a players annual injury rate per gamae

# %%
inj_dict = {}
name = full_df.iloc[0]['Name']
N_injs = 0
N_games = 0
season = "2010-11"
players_failed = []

for i,r in full_df.iterrows():
    
    name_tmp = r['Name']
    date = r['Date']
    date = str2datetime(date)
    yr = date.year if date < datetime.datetime(date.year,8,1) else date.year+1
    
    season_tmp = "{}-{}".format(yr-1,str(yr)[2:])
    
    if name_tmp == name and season_tmp == season:
        N_games +=1
        if r['Was_Injured?'] == 1:
            N_injs += 1   
    else:
        try:
            inj_dict[name,season] = N_injs/N_games
        except ZeroDivisionError:
            players_failed.append(name) #Catch players for which this fails
    
    if name_tmp != name:
        N_games = 1
        N_injs = 1 if r['Was_Injured?']==1 else 0
        name = name_tmp
        season = season_tmp     
    elif season_tmp != season:
        season = season_tmp
        N_games += 1

# %%
players_failed
# Out:
# []

# %%
def ann_inj_rate(row):
    
    name = row['Name']
    date = row['Date']
    date = str2datetime(date)
    yr = date.year if date < datetime.datetime(date.year,8,1) else date.year+1
    prev_yr = yr-1
    
    season = "{}-{}".format(prev_yr-1,str(prev_yr)[2:])
    
    try:
        rate = inj_dict[name,season]
        return rate
    except KeyError:
        return 0

# %%
full_df['ann_inj_rate'] = full_df.apply(lambda row: ann_inj_rate(row), axis=1)

# %%
for c in full_df.columns:
    print(c)
# Out:
# Name
# Height [cm]
# Weight [kg]
# Position
# Pos3
# Shoots
# Date
# Age
# Opp
# MP
# FG
# FGA
# FG%
# 3P
# 3PA
# 3P%
# FT
# FTA
# FT%
# ORB
# DRB
# TRB
# AST
# STL
# BLK
# TOV
# PF
# PTS
# GmSc
# +/-
# Was_Injured?
# Notes
# MP_Av7
# FG_Av7
# FGA_Av7
# FG%_Av7
# 3P_Av7
# 3PA_Av7
# 3P%_Av7
# FT_Av7
# FTA_Av7
# FT%_Av7
# ORB_Av7
# DRB_Av7
# TRB_Av7
# AST_Av7
# STL_Av7
# BLK_Av7
# TOV_Av7
# PF_Av7
# PTS_Av7
# GmSc_Av7
# +/-_Av7
# N_games_7
# MP_Av14
# FG_Av14
# FGA_Av14
# FG%_Av14
# 3P_Av14
# 3PA_Av14
# 3P%_Av14
# FT_Av14
# FTA_Av14
# FT%_Av14
# ORB_Av14
# DRB_Av14
# TRB_Av14
# AST_Av14
# STL_Av14
# BLK_Av14
# TOV_Av14
# PF_Av14
# PTS_Av14
# GmSc_Av14
# +/-_Av14
# N_games_14
# MP_Av21
# FG_Av21
# FGA_Av21
# FG%_Av21
# 3P_Av21
# 3PA_Av21
# 3P%_Av21
# FT_Av21
# FTA_Av21
# FT%_Av21
# ORB_Av21
# DRB_Av21
# TRB_Av21
# AST_Av21
# STL_Av21
# BLK_Av21
# TOV_Av21
# PF_Av21
# PTS_Av21
# GmSc_Av21
# +/-_Av21
# N_games_21
# MP_b2b
# FG_b2b
# FGA_b2b
# FG%_b2b
# 3P_b2b
# 3PA_b2b
# 3P%_b2b
# FT_b2b
# FTA_b2b
# FT%_b2b
# ORB_b2b
# DRB_b2b
# TRB_b2b
# AST_b2b
# STL_b2b
# BLK_b2b
# TOV_b2b
# PF_b2b
# PTS_b2b
# GmSc_b2b
# +/-_b2b
# b2b
# N_prev_injs
# ann_inj_rate

# %% [markdown]
# ### Merge windowed df with speed distance dataframe

# %%
cols = ['Date','Name']
injs_speed_dist = full_df.merge(speed_dist_full,how='inner',left_on=cols,right_on=cols)
injs_speed_dist.drop_duplicates(subset=['Name','Date'],inplace=True)

# %% [markdown]
# ### Drop players who averaged less than 15 minutes per game in our dataset

# %%
grouped = injs_speed_dist.groupby(['Name'])
injs_filt = grouped.filter(lambda x: x['MP'].mean()>15)

# %%
injs_filt
# Out:
#                    Name  Height [cm]  Weight [kg]                  Position  \
# 0          Aaron Brooks          183           73               Point Guard
# 1          Aaron Brooks          183           73               Point Guard
# 2          Aaron Brooks          183           73               Point Guard
# 3          Aaron Brooks          183           73               Point Guard
# 4          Aaron Brooks          183           73               Point Guard
# 5          Aaron Brooks          183           73               Point Guard
# 6          Aaron Brooks          183           73               Point Guard
# 7          Aaron Brooks          183           73               Point Guard
# 8          Aaron Brooks          183           73               Point Guard
# 9          Aaron Brooks          183           73               Point Guard
# 10         Aaron Brooks          183           73               Point Guard
# 11         Aaron Brooks          183           73               Point Guard
# 12         Aaron Brooks          183           73               Point Guard
# 13         Aaron Brooks          183           73               Point Guard
# 14         Aaron Brooks          183           73               Point Guard
# 15         Aaron Brooks          183           73               Point Guard
# 16         Aaron Brooks          183           73               Point Guard
# 17         Aaron Brooks          183           73               Point Guard
# 18         Aaron Brooks          183           73               Point Guard
# 19         Aaron Brooks          183           73               Point Guard
# 20         Aaron Brooks          183           73               Point Guard
# 21         Aaron Brooks          183           73               Point Guard
# 22         Aaron Brooks          183           73               Point Guard
# 23         Aaron Brooks          183           73               Point Guard
# 24         Aaron Brooks          183           73               Point Guard
# 25         Aaron Brooks          183           73               Point Guard
# 26         Aaron Brooks          183           73               Point Guard
# 27         Aaron Brooks          183           73               Point Guard
# 28         Aaron Brooks          183           73               Point Guard
# 29         Aaron Brooks          183           73               Point Guard
# ...                 ...          ...          ...                       ...
# 149100    Zach Randolph          206          113  Center and Power Forward
# 149101    Zach Randolph          206          113  Center and Power Forward
# 149102    Zach Randolph          206          113  Center and Power Forward
# 149103    Zach Randolph          206          113  Center and Power Forward
# 149104    Zach Randolph          206          113  Center and Power Forward
# 149105    Zach Randolph          206          113  Center and Power Forward
# 149106    Zach Randolph          206          113  Center and Power Forward
# 149107    Zach Randolph          206          113  Center and Power Forward
# 149108    Zach Randolph          206          113  Center and Power Forward
# 149109    Zach Randolph          206          113  Center and Power Forward
# 149110    Zach Randolph          206          113  Center and Power Forward
# 149111    Zach Randolph          206          113  Center and Power Forward
# 149137  Zion Williamson          198          129             Power Forward
# 149138  Zion Williamson          198          129             Power Forward
# 149139  Zion Williamson          198          129             Power Forward
# 149140  Zion Williamson          198          129             Power Forward
# 149141  Zion Williamson          198          129             Power Forward
# 149142  Zion Williamson          198          129             Power Forward
# 149143  Zion Williamson          198          129             Power Forward
# 149144  Zion Williamson          198          129             Power Forward
# 149145  Zion Williamson          198          129             Power Forward
# 149146  Zion Williamson          198          129             Power Forward
# 149147  Zion Williamson          198          129             Power Forward
# 149148  Zion Williamson          198          129             Power Forward
# 149149  Zion Williamson          198          129             Power Forward
# 149150  Zion Williamson          198          129             Power Forward
# 149151  Zion Williamson          198          129             Power Forward
# 149152  Zion Williamson          198          129             Power Forward
# 149153  Zion Williamson          198          129             Power Forward
# 149154  Zion Williamson          198          129             Power Forward
#
#          Pos3 Shoots        Date        Age  Opp         MP  ...  \
# 0       Guard  Right  2013-11-01  28.796715  DAL  22.950000  ...
# 1       Guard  Right  2013-11-02  28.799452  UTA  20.566667  ...
# 2       Guard  Right  2013-11-04  28.804928  LAC  17.516667  ...
# 3       Guard  Right  2013-11-05  28.807666  POR   1.016667  ...
# 4       Guard  Right  2013-11-11  28.824093  TOR   0.100000  ...
# 5       Guard  Right  2013-11-13  28.829569  PHI   4.383333  ...
# 6       Guard  Right  2013-11-14  28.832307  NYK   0.033333  ...
# 7       Guard  Right  2013-11-16  28.837782  DEN   1.000000  ...
# 8       Guard  Right  2013-11-19  28.845996  BOS   9.183333  ...
# 9       Guard  Right  2013-11-23  28.856947  MIN  24.600000  ...
# 10      Guard  Right  2013-11-25  28.862423  MEM  16.183333  ...
# 11      Guard  Right  2013-11-27  28.867899  ATL  27.483333  ...
# 12      Guard  Right  2013-11-29  28.873374  BRK  28.250000  ...
# 13      Guard  Right  2013-11-30  28.876112  SAS  15.866667  ...
# 14      Guard  Right  2013-12-02  28.881588  UTA  24.016667  ...
# 15      Guard  Right  2013-12-04  28.887064  PHO  33.450000  ...
# 16      Guard  Right  2013-12-06  28.892539  GSW  17.050000  ...
# 17      Guard  Right  2013-12-08  28.898015  ORL  13.283333  ...
# 18      Guard  Right  2013-12-15  28.917180  SAC  27.316667  ...
# 19      Guard  Right  2013-12-18  28.925394  CHI  17.633333  ...
# 20      Guard  Right  2013-12-20  28.930869  IND  17.983333  ...
# 21      Guard  Right  2013-12-21  28.933607  DET  34.433333  ...
# 22      Guard  Right  2013-12-23  28.939083  DAL  27.216667  ...
# 23      Guard  Right  2013-12-25  28.944559  SAS  14.133333  ...
# 24      Guard  Right  2013-12-26  28.947296  MEM  14.866667  ...
# 25      Guard  Right  2013-12-28  28.952772  NOP  20.150000  ...
# 26      Guard  Right  2013-12-29  28.955510  OKC  23.433333  ...
# 27      Guard  Right  2013-12-31  28.960986  SAC  14.633333  ...
# 19                      4.31        5        3            8882.6
# 20                      4.15        5        3            8369.5
# 21                      4.22        5        4            8202.7
# 22                      4.13        4        4              8727
# 23                      4.01        4        4            8887.6
# 24                      4.08        5        4            8485.2
# 25                      4.08        6        3            7656.8
# 26                      4.07        6        3            7747.3
# 27                      4.04        5        4            8146.4
# 28                      4.08        5        5            7875.9
# 29                      4.02        6        4            7502.1
# ...                      ...      ...      ...               ...
# 149100                  3.84        3        4            9417.4
# 149101                  3.90        3        4            9800.3
# 149102                  3.93        3        5            9776.0
# 149103                  3.80        2        5            9872.1
# 149104                  3.83        2        4            9793.8
# 149105                  3.85        1        5            9766.7
# 149106                  3.82        1        4            9744.0
# 149107                  3.78        0        5            9722.6
# 149108                  3.79        0        6            9359.3
# 149109                  3.76        0        7            9193.1
# 149110                  3.89        1        7            9503.8
# 149111                  3.92        2        5            8795.4
# 149137                  4.04        0        1            7764.0
# 149138                  3.83        0        2            8191.5
# 149139                  4.02        1        2            9084.7
# 149140                  3.88        2        2            9771.5
# 149141                  4.02        3        2           10273.6
# 149142                  4.02        3        3           10795.5
# 149143                  3.99        3        4           11193.7
# 149144                  4.00        4        4           11011.9
# 149145                  3.95        5        4           11011.7
# 149146                  3.74        3        3           12149.2
# 149147                  3.73        3        3           12071.3
# 149148                  3.84        4        2           12044.7
# 149149                  3.89        4        2           12055.2
# 149150                  3.79        4        2           12481.2
# 149151                  3.84        4        3           12618.4
# 149152                  3.90        4        4           12700.4
# 149153                  3.90        3        4           12941.9
# 149154                  3.90        4        3           12932.6
#
#         Dist Miles_Av_21  Dist Miles Off._Av_21  Dist Miles Def._Av_21  \
# 0                   0.85                   0.40                   0.45
# 1                   1.29                   0.65                   0.64
# 2                   1.34                   0.66                   0.68
# 3                   1.32                   0.65                   0.67
# 4                   1.07                   0.52                   0.54
# 5                   0.89                   0.44                   0.45
# 6                   0.81                   0.40                   0.41
# 7                   0.71                   0.35                   0.36
# 8                   0.64                   0.31                   0.32
# 9                   0.62                   0.31                   0.31
# 10                  0.53                   0.26                   0.27
# 11                  0.52                   0.26                   0.26
# 12                  0.76                   0.38                   0.38
# 13                  0.88                   0.44                   0.44
# 14                  0.92                   0.47                   0.45
# 15                  1.09                   0.55                   0.54
# 16                  1.30                   0.66                   0.65
# 17                  1.43                   0.73                   0.70
# 18                  1.61                   0.82                   0.79
# 19                  1.68                   0.87                   0.82
# 20                  1.59                   0.82                   0.77
# 21                  1.55                   0.80                   0.75
# 22                  1.65                   0.86                   0.79
# 23                  1.68                   0.87                   0.81
# 24                  1.61                   0.83                   0.77
# 25                  1.45                   0.76                   0.69
# 26                  1.47                   0.76                   0.70
# 27                  1.54                   0.80                   0.74
# 28                  1.49                   0.78                   0.71
# 29                  1.42                   0.74                   0.68
# ...                  ...                    ...                    ...
# 149100              1.78                   0.94                   0.85
# 149101              1.86                   0.98                   0.88
# 149102              1.85                   0.97                   0.88
# 149103              1.87                   1.00                   0.87
# 149104              1.85                   0.99                   0.87
# 149105              1.85                   0.98                   0.87
# 149148             4.36                  4.98                  3.82
# 149149             4.32                  4.96                  3.77
# 149150             4.34                  4.93                  3.78
# 149151             4.32                  4.90                  3.82
# 149152             4.33                  4.90                  3.87
# 149153             4.36                  4.83                  3.89
# 149154             4.30                  4.78                  3.87
#
# [133072 rows x 150 columns]

# %% [markdown]
# ### Get rid of columns that correspond to the score in that game, as well as Notes

# %%
injs_filt.drop(columns=injs_filt.columns[9:30],inplace=True)
injs_filt.drop(columns='Notes',inplace=True)

# %%
for c in injs_filt.columns:
    print(c)
# Out:
# Name
# Height [cm]
# Weight [kg]
# Position
# Pos3
# Shoots
# Date
# Age
# Opp
# Was_Injured?
# MP_Av7
# FG_Av7
# FGA_Av7
# FG%_Av7
# 3P_Av7
# 3PA_Av7
# 3P%_Av7
# FT_Av7
# FTA_Av7
# FT%_Av7
# ORB_Av7
# DRB_Av7
# TRB_Av7
# AST_Av7
# STL_Av7
# BLK_Av7
# TOV_Av7
# PF_Av7
# PTS_Av7
# GmSc_Av7
# +/-_Av7
# N_games_7
# MP_Av14
# FG_Av14
# FGA_Av14
# FG%_Av14
# 3P_Av14
# 3PA_Av14
# 3P%_Av14
# FT_Av14
# FTA_Av14
# FT%_Av14
# ORB_Av14
# DRB_Av14
# TRB_Av14
# AST_Av14
# STL_Av14
# BLK_Av14
# TOV_Av14
# PF_Av14
# PTS_Av14
# GmSc_Av14
# +/-_Av14
# N_games_14
# MP_Av21
# FG_Av21
# FGA_Av21
# FG%_Av21
# 3P_Av21
# 3PA_Av21
# 3P%_Av21
# FT_Av21
# FTA_Av21
# FT%_Av21
# ORB_Av21
# DRB_Av21
# TRB_Av21
# AST_Av21
# STL_Av21
# BLK_Av21
# TOV_Av21
# PF_Av21
# PTS_Av21
# GmSc_Av21
# +/-_Av21
# N_games_21
# MP_b2b
# FG_b2b
# FGA_b2b
# FG%_b2b
# 3P_b2b
# 3PA_b2b
# 3P%_b2b
# FT_b2b
# FTA_b2b
# FT%_b2b
# ORB_b2b
# DRB_b2b
# TRB_b2b
# AST_b2b
# STL_b2b
# BLK_b2b
# TOV_b2b
# PF_b2b
# PTS_b2b
# GmSc_b2b
# +/-_b2b
# b2b
# N_prev_injs
# ann_inj_rate
# Team
# W_Av_7
# L_Av_7
# Dist. Feet_Av_7
# Dist Miles_Av_7
# Dist Miles Off._Av_7
# Dist Miles Def._Av_7
# Avg Speed_Av_7
# Avg Speed Off._Av_7
# Avg Speed Def._Av_7
# W_Av_14
# L_Av_14
# Dist. Feet_Av_14
# Dist Miles_Av_14
# Dist Miles Off._Av_14
# Dist Miles Def._Av_14
# Avg Speed_Av_14
# Avg Speed Off._Av_14
# Avg Speed Def._Av_14
# W_Av_21
# L_Av_21
# Dist. Feet_Av_21
# Dist Miles_Av_21
# Dist Miles Off._Av_21
# Dist Miles Def._Av_21
# Avg Speed_Av_21
# Avg Speed Off._Av_21
# Avg Speed Def._Av_21

# %%
injs_filt.shape
# Out:
# (133072, 128)

# %%
injs_filt.to_csv('inj_data_final.csv')
