# %%
import pandas as pd
import numpy as np

import datetime

def str2datetime(date):
    
    date_tmp = date.split('-')
    
    y = int(date_tmp[0])
    m = int(date_tmp[1])
    d = int(date_tmp[2])
    
    return datetime.datetime(y,m,d)

# %%
inj_df = pd.read_csv('nba_games_2010_20.csv')
inj_df = inj_df.loc[inj_df['Age'] != 0]
inj_df = inj_df.drop(columns='Unnamed: 0')

# %%
inj_df
# Out:
#                     Name  Height [cm]  Weight [kg]  \
# 0          Carlos Boozer          206          117
# 1          Carlos Boozer          206          117
# 2          Carlos Boozer          206          117
# 3          Carlos Boozer          206          117
# 4          Carlos Boozer          206          117
# 5          Carlos Boozer          206          117
# 6          Carlos Boozer          206          117
# 7          Jonas Jerebko          208          104
# 8            Troy Murphy          211          111
# 9            Troy Murphy          211          111
# 10           Troy Murphy          211          111
# 11           Troy Murphy          211          111
# 12           Troy Murphy          211          111
# 13         Al Harrington          206          104
# 14         Al Harrington          206          104
# 15         Al Harrington          206          104
# 16         Al Harrington          206          104
# 17         Al Harrington          206          104
# 18         Al Harrington          206          104
# 19      Samuel Dalembert          211          115
# 20      Samuel Dalembert          211          115
# 21       Dominic McGuire          206           99
# 22       Dominic McGuire          206           99
# 23       Dominic McGuire          206           99
# 24       Dominic McGuire          206           99
# 25       Dominic McGuire          206           99
# 26        Josh Childress          203           95
# 27         Nick Collison          208          115
# 28         Nick Collison          208          115
# 29         Nick Collison          208          115
# ...                  ...          ...          ...
# 258237       Isaac Bonga          203           81
# 258238       Isaac Bonga          203           81
# 258239       Isaac Bonga          203           81
# 258240       Isaac Bonga          203           81
# 258241       Isaac Bonga          203           81
# 258242       Isaac Bonga          203           81
# 258243       Isaac Bonga          203           81
# 258244       Isaac Bonga          203           81
# 258245       Isaac Bonga          203           81
# 258246       Isaac Bonga          203           81
# 258247       Isaac Bonga          203           81
# 258248       Isaac Bonga          203           81
# 258249       Isaac Bonga          203           81
# 258250       Isaac Bonga          203           81
# 258251       Isaac Bonga          203           81
# 258252       Isaac Bonga          203           81
# 258253       Isaac Bonga          203           81
# 258254       Isaac Bonga          203           81
# 258255       Isaac Bonga          203           81
# 258256       Isaac Bonga          203           81
# 258257       Isaac Bonga          203           81
# 258258       Isaac Bonga          203           81
# 258259       Isaac Bonga          203           81
# 258260       Isaac Bonga          203           81
# 258261       Isaac Bonga          203           81
# 258262       Isaac Bonga          203           81
# 258263       Isaac Bonga          203           81
# 258264       Isaac Bonga          203           81
# 258265       Isaac Bonga          203           81
# 258266       Isaac Bonga          203           81
#
#                                                  Position  Pos3 Shoots  \
# 0                                Center and Power Forward   Big  Right
# 1                                Center and Power Forward   Big  Right
# 2                                Center and Power Forward   Big  Right
# 3                                Center and Power Forward   Big  Right
# 4                                Center and Power Forward   Big  Right
# 5                                Center and Power Forward   Big  Right
# 6                                Center and Power Forward   Big  Right
# 7                                           Power Forward   Big  Right
# 8                                           Power Forward   Big   Left
# 9                                           Power Forward   Big   Left
# 10                                          Power Forward   Big   Left
# 11                                          Power Forward   Big   Left
# 12                                          Power Forward   Big   Left
# 13             Center and Power Forward and Small Forward   Big  Right
# 14             Center and Power Forward and Small Forward   Big  Right
# 15             Center and Power Forward and Small Forward   Big  Right
# 16             Center and Power Forward and Small Forward   Big  Right
# 17             Center and Power Forward and Small Forward   Big  Right
# 18             Center and Power Forward and Small Forward   Big  Right
# 19                                                 Center   Big  Right
# 20                                                 Center   Big  Right
# 21      Power Forward and Small Forward and Shooting G...  Wing  Right
# 22      Power Forward and Small Forward and Shooting G...  Wing  Right
# 23      Power Forward and Small Forward and Shooting G...  Wing  Right
# 24      Power Forward and Small Forward and Shooting G...  Wing  Right
# 25      Power Forward and Small Forward and Shooting G...  Wing  Right
# 26                       Small Forward and Shooting Guard  Wing  Right
# 27                               Center and Power Forward   Big  Right
# 28                               Center and Power Forward   Big  Right
# 29                               Center and Power Forward   Big  Right
# ...                                                   ...   ...    ...
# 258237                      Point Guard and Small Forward  Wing  Right
# 258238                      Point Guard and Small Forward  Wing  Right
# 258239                      Point Guard and Small Forward  Wing  Right
# 258240                      Point Guard and Small Forward  Wing  Right
# 258241                      Point Guard and Small Forward  Wing  Right
# 258242                      Point Guard and Small Forward  Wing  Right
# 258243                      Point Guard and Small Forward  Wing  Right
# 258244                      Point Guard and Small Forward  Wing  Right
# 258245                      Point Guard and Small Forward  Wing  Right
# 258246                      Point Guard and Small Forward  Wing  Right
# 258247                      Point Guard and Small Forward  Wing  Right
# 258248                      Point Guard and Small Forward  Wing  Right
# 258249                      Point Guard and Small Forward  Wing  Right
# 258250                      Point Guard and Small Forward  Wing  Right
# 258251                      Point Guard and Small Forward  Wing  Right
# 258252                      Point Guard and Small Forward  Wing  Right
# 258253                      Point Guard and Small Forward  Wing  Right
# 258254                      Point Guard and Small Forward  Wing  Right
# 258255                      Point Guard and Small Forward  Wing  Right
# 258256                      Point Guard and Small Forward  Wing  Right
# 258257                      Point Guard and Small Forward  Wing  Right
# 258258                      Point Guard and Small Forward  Wing  Right
# 258259                      Point Guard and Small Forward  Wing  Right
# 258260                      Point Guard and Small Forward  Wing  Right
# 258261                      Point Guard and Small Forward  Wing  Right
# 258262                      Point Guard and Small Forward  Wing  Right
# 258263                      Point Guard and Small Forward  Wing  Right
# 258264                      Point Guard and Small Forward  Wing  Right
# 258265                      Point Guard and Small Forward  Wing  Right
# 258266                      Point Guard and Small Forward  Wing  Right
#
#               Date        Age  Opp         MP  ...  AST  STL  BLK  TOV  PF  \
# 0       2011-01-15  29.153320  MIA  35.500000  ...    3    0    1    2   2
# 1       2011-03-09  29.298426  CHA  26.466667  ...    1    0    1    3   4
# 2       2013-01-28  31.188912  CHA  26.816667  ...    1    0    0    1   4
# 3       2014-01-02  32.117728  BOS  29.833333  ...    0    1    0    1   3
# 4       2014-01-20  32.167009  LAL  28.016667  ...    4    0    0    0   2
# 5       2014-02-04  32.208077  PHO  31.800000  ...    1    1    1    1   2
# 6       2014-11-21  33.002738  DAL  19.783333  ...    2    0    0    0   3
# 7       2016-03-15  29.035592  IND  26.283333  ...    2    0    0    1   2
# 8       2010-11-09  30.522930  CLE  24.733333  ...    1    0    0    1   2
# 9       2010-11-13  30.533881  ORL   8.433333  ...    0    0    0    0   2
# 10      2010-12-09  30.605065  DAL  11.016667  ...    0    0    0    0   1
# 11      2011-01-07  30.684463  WAS  10.633333  ...    0    0    0    0   1
# 12      2011-03-23  30.889802  MEM   3.683333  ...    0    0    0    2   0
# 13      2010-12-26  30.854209  PHI   3.966667  ...    0    0    0    1   0
# 14      2011-01-28  30.944559  CLE  25.683333  ...    3    0    0    1   5
# 15      2011-03-16  31.073922  ATL  13.183333  ...    0    0    0    0   1
# 16      2012-04-21  32.175222  PHO  22.850000  ...    1    1    0    0   3
# 17      2013-03-15  33.071184  OKC   6.050000  ...    0    0    0    0   2
# 18      2013-11-12  33.733744  DAL  19.083333  ...    0    1    0    0   3
# 19      2013-02-23  31.791239  ATL  15.666667  ...    1    1    0    1   2
# 20      2014-12-27  33.632444  SAC  18.800000  ...    0    0    4    0   5
# 21      2010-12-21  25.169747  OKC   1.750000  ...    0    0    0    0   2
# 22      2011-01-31  25.281999  UTA   2.350000  ...    0    1    0    0   2
# 23      2011-02-04  25.292950  MIA   3.966667  ...    0    0    0    0   0
# 24      2011-02-11  25.312115  NJN  10.233333  ...    0    0    0    0   1
# 25      2012-02-09  26.306639  DEN   4.350000  ...    0    0    1    2   1
# 26      2012-12-09  29.470910  MIL   3.716667  ...    0    0    0    0   0
# 27      2011-03-27  30.416153  POR  23.466667  ...    0    0    1    1   3
# 28      2011-04-11  30.457221  SAC  19.050000  ...    2    1    1    1   4
# 29      2012-02-19  31.317591  DEN  20.666667  ...    1    0    0    0   2
# ...            ...        ...  ...        ...  ...  ...  ...  ...  ...  ..
# 258237  2020-02-23  20.292950  CHI  15.183333  ...    0    0    0    1   3
# 258238  2020-02-24  20.295688  MIL  24.016667  ...    0    1    0    1   4
# 258239  2020-02-26  20.301164  BRK  16.666667  ...    1    0    1    1   2
# 258240  2020-02-28  20.306639  UTA  12.666667  ...    2    0    0    1   2
# 258241  2020-03-01  20.312115  GSW  21.450000  ...    1    0    1    1   4
# 258242  2020-03-03  20.317591  SAC   9.583333  ...    0    0    0    0   2
# 258243  2020-03-04  20.320329  POR  27.966667  ...    3    2    0    1   3
# 258244  2020-03-06  20.325804  ATL  12.233333  ...    0    0    1    1   1
# 258245  2018-12-07  19.079398  SAS   1.116667  ...    0    0    0    0   0
# 258246  2018-12-08  19.082136  MEM   4.416667  ...    1    1    0    2   2
# 258247  2018-12-13  19.095825  HOU   1.000000  ...    0    0    0    0   0
# 258248  2018-12-15  19.101300  CHO   6.416667  ...    1    2    0    0   1
# 258249  2018-12-16  19.104038  WAS   3.900000  ...    1    0    0    0   0
# 258250  2019-01-06  19.161533  MIN   5.000000  ...    1    0    0    0   0
# 258251  2019-01-21  19.202601  GSW   6.533333  ...    1    0    0    0   0
# 258252  2019-02-02  19.235455  GSW   2.133333  ...    1    0    0    0   0
# 258253  2019-03-06  19.323066  DEN   2.216667  ...    1    0    0    1   0
# 258254  2019-03-09  19.331280  BOS   5.700000  ...    0    0    1    1   0
# 258255  2019-03-15  19.347707  DET   5.116667  ...    0    0    0    0   0
# 258256  2019-03-19  19.358658  MIL   1.350000  ...    0    0    0    0   0
# 258257  2019-03-22  19.366872  BRK   0.083333  ...    0    0    0    0   0
# 258258  2019-03-26  19.377823  WAS   1.100000  ...    0    0    0    0   0
# 258259  2019-03-27  19.380561  UTA  10.650000  ...    1    1    0    0   1
# 258260  2019-03-29  19.386037  CHO   1.083333  ...    0    0    0    0   0
# 258261  2019-03-31  19.391513  NOP  10.700000  ...    1    2    0    0   1
# 258262  2019-04-02  19.396988  OKC   1.066667  ...    0    0    0    0   0
# 258263  2019-04-04  19.402464  GSW   8.616667  ...    2    1    1    0   0
# 258264  2019-04-05  19.405202  LAC  13.350000  ...    2    1    1    0   2
# 258265  2019-04-07  19.410678  UTA  19.383333  ...    2    1    0    2   2
# 258266  2019-04-09  19.416153  POR   9.066667  ...    0    0    1    0   0
#
#         PTS  GmSc   +/-  Was_Injured?  \
# 0        12   8.8   0.0           1.0
# 1        10   4.6  14.0           1.0
# 2        13   4.8 -12.0           1.0
# 3        16   8.9   4.0           1.0
# 4        11   5.6   5.0           1.0
# 5        19  13.3   5.0           1.0
# 6        12   6.4  -3.0           1.0
# 7        17  11.9  -8.0           1.0
# 8         5   4.9   2.0           1.0
# 9         2   1.1  12.0           1.0
# 10        0  -0.9  -7.0           1.0
# 11        4   3.9   0.0           1.0
# 12        0  -2.0  -6.0           1.0
# 13        3   1.3   3.0           1.0
# 14        2  -0.6   7.0           1.0
# 15        9   8.0  -3.0           1.0
# 16        8   6.5 -13.0           1.0
# 17        0  -0.8 -18.0           1.0
# 18        8   4.0 -12.0           1.0
# 19        4   3.4  -1.0           1.0
# 20       11   8.7  -9.0           1.0
# 21        1   0.5   0.0           1.0
# 22        0   0.5   1.0           1.0
# 23        0   0.0  -4.0           1.0
# 24        0  -0.2   8.0           1.0
# 25        0  -2.4  -8.0           1.0
# 26        0  -0.7  -6.0           1.0
# 27        4   2.7   2.0           1.0
# 28        4   3.5   9.0           1.0
# 29        3   2.9 -15.0           1.0
# ...     ...   ...   ...           ...
# 258237    2  -0.9   2.0           0.0
# 258238    0   0.5 -17.0           0.0
# 258239    3   3.5   6.0           0.0
# 258240    0   0.2   7.0           0.0
# 258241    6   3.1  15.0           0.0
# 258242    2   0.5 -15.0           0.0
# 258243    7   8.3   8.0           0.0
# 258244    7   5.7  -6.0           0.0
# 258245    0   0.0   0.0           0.0
# 258246    1  -0.5  -1.0           0.0
# 258247    0  -0.7  -2.0           0.0
# 258248    2   3.3  -6.0           0.0
# 258249    3   3.3   0.0           0.0
# 258250    0   0.0   3.0           0.0
# 258251    2   1.9   5.0           0.0
# 258252    0   0.3   4.0           0.0
# 258253    2   2.0  -1.0           0.0
# 258254    0   0.0  -9.0           0.0
# 258255    0  -0.8  -2.0           0.0
# 258256    0   0.0  -2.0           0.0
# 258257    0   0.0  -1.0           0.0
# 258258    0   0.0   5.0           0.0
# 258259    2   2.5   3.0           0.0
# 258260    0  -0.7  -3.0           0.0
# 258261    2   1.8  14.0           0.0
# 258262    0  -0.7   0.0           0.0
# 258263    4   7.3   5.0           0.0
# 258264    1   1.8   8.0           0.0
# 258265    0  -2.2  -2.0           0.0
# 258266    0   0.7  -5.0           0.0
#
#                                                    Notes
# 0                              sprained left ankle (DNP)
# 1                  placed on IL with sprained left ankle
# 2                         strained right hamstring (DNP)
# 3                          sore/bruised right knee (DNP)
# 4                                 left calf injury (DNP)
# 5                               strained left calf (DNP)
# 6                           strained left shoulder (DTD)
# 7                      placed on IL with sore left ankle
# 8                      placed on IL with sore right foot
# 9                      placed on IL with sore right foot
# 10                                          placed on IL
# 11                                          placed on IL
# 12                            sprained right ankle (DNP)
# 13              placed on IL with dislocated right thumb
# 14                    placed on IL with left foot injury
# 15      placed on IL with strained right Achilles tendon
# 16                               right knee injury (DNP)
# 17                                                   DNP
# 18                                 sore right knee (DTD)
# 19                                          placed on IL
# 20                            sprained right ankle (DTD)
# 21                                          placed on IL
# 22                                          placed on IL
# 23                                          placed on IL
# 24                                          placed on IL
# 25                         strained/sore left knee (DNP)
# 26                      placed on IL with sore left foot
# 27                             sprained left ankle (DNP)
# 28                         placed on IL (out for season)
# 29                         bruised left quadriceps (DNP)
# ...                                                  ...
# 258237                                         No injury
# 258238                                         No injury
# 258239                                         No injury
# 258240                                         No injury
# 258241                                         No injury
# 258242                                         No injury
# 258243                                         No injury
# 258244                                         No injury
# 258245                                         No injury
# 258246                                         No injury
# 258247                                         No injury
# 258248                                         No injury
# 258249                                         No injury
# 258250                                         No injury
# 258251                                         No injury
# 258252                                         No injury
# 258253                                         No injury
# 258254                                         No injury
# 258255                                         No injury
# 258256                                         No injury
# 258257                                         No injury
# 258258                                         No injury
# 258259                                         No injury
# 258260                                         No injury
# 258261                                         No injury
# 258262                                         No injury
# 258263                                         No injury
# 258264                                         No injury
# 258265                                         No injury
# 258266                                         No injury
#
# [258267 rows x 32 columns]

# %% [markdown]
# ### Sort values by Name and Date for Windowing

# %%
inj_df = inj_df.sort_values(by=['Name','Date']).reset_index(drop=True)

# %% [markdown]
# #### Start with 7 day window

# %%
time_window = datetime.timedelta(days=7) #Changes the time window

window_arr = []

for idx in range(inj_df.shape[0]):
    
    idx_end = idx
    idx_start = idx

    current_row = inj_df.iloc[idx]
    date_game = str2datetime(current_row['Date'])
    
    if idx%10000==0:
        print("On index {}, player is {}".format(idx,current_row['Name']))

    in_window = True

    while(in_window):
        #Run backwards through dataframe, finding the first game that's out of the window or is a different player
        row = inj_df.iloc[idx_end-1]
        in_window = (current_row['Name'] == row['Name']) and (date_game - str2datetime(row['Date']) <= time_window)
        if in_window:
            idx_end -= 1

    games_window = inj_df.iloc[idx_end:idx_start].loc[:,'MP':'+/-']
    
    window_mean = games_window.mean()
    
    #Correctly compute average FG%, 3P%, FT%
    window_mean['FG%'] = games_window['FG'].sum()/games_window['FGA'].sum()
    window_mean['3P%'] = games_window['3P'].sum()/games_window['3PA'].sum()
    window_mean['FT%'] = games_window['FT'].sum()/games_window['FT%'].sum()
    
    window_mean = np.concatenate((window_mean,[len(games_window)])) #Add column of N_games in time window
    
    window_arr.append(window_mean)
    
window_arr = np.array(window_arr)
# Out:
# On index 0, player is (William) Tony Parker
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:30: RuntimeWarning: invalid value encountered in long_scalars
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:31: RuntimeWarning: invalid value encountered in long_scalars
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:32: RuntimeWarning: invalid value encountered in true_divide
# On index 10000, player is Andre Drummond
# On index 20000, player is Ben McLemore
# On index 30000, player is Buddy Hield
# On index 40000, player is Chris Wright (b)
# On index 50000, player is Dante Cunningham
# On index 60000, player is Dennis Smith Jr.
# On index 70000, player is Dwayne Bacon
# On index 80000, player is Evan Fournier
# On index 90000, player is Greg Monroe
# On index 100000, player is J.R. Smith
# On index 110000, player is Jarrett Allen
# On index 120000, player is Jimmy Butler
# On index 130000, player is Jordan Hill
# On index 140000, player is Kemba Walker
# On index 150000, player is Kurt Thomas
# On index 160000, player is Louis Williams
# On index 170000, player is Mario Chalmers
# On index 180000, player is Mike Conley Jr.
# On index 190000, player is Nikola Mirotic
# On index 200000, player is Paul Millsap
# On index 210000, player is Robert Covington
# On index 220000, player is Serge Ibaka
# On index 230000, player is T.J. McConnell
# On index 240000, player is Tony Allen
# On index 250000, player is Victor Oladipo

# %% [markdown]
# #### Add this on to our exisiting dataframe, and save the result

# %%
inj_window = inj_df.copy()

averaged_columns = inj_df.columns[9:30]

for i,col in enumerate(averaged_columns):
    col_tag = col + "_Av7"
    inj_window[col_tag] = window_arr[:,i]
    
inj_window['N_games_7'] = window_arr[:,-1]

# %%
inj_window.to_csv('injs_avg7.csv')

# %% [markdown]
# ### 14 day window

# %%
time_window = datetime.timedelta(days=14) #Changes the time window

window_arr = []

for idx in range(inj_df.shape[0]):
    
    idx_end = idx
    idx_start = idx

    current_row = inj_df.iloc[idx]
    date_game = str2datetime(current_row['Date'])
    
    if idx%10000==0:
        print("On index {}, player is {}".format(idx,current_row['Name']))

    in_window = True

    while(in_window):
        #Run backwards through dataframe, finding the first game that's out of the window or is a different player
        row = inj_df.iloc[idx_end-1]
        in_window = (current_row['Name'] == row['Name']) and (date_game - str2datetime(row['Date']) <= time_window)
        if in_window:
            idx_end -= 1

    games_window = inj_df.iloc[idx_end:idx_start].loc[:,'MP':'+/-']
    
    window_mean = games_window.mean()
    
    #Correctly compute average FG%, 3P%, FT%
    window_mean['FG%'] = games_window['FG'].sum()/games_window['FGA'].sum()
    window_mean['3P%'] = games_window['3P'].sum()/games_window['3PA'].sum()
    window_mean['FT%'] = games_window['FT'].sum()/games_window['FT%'].sum()
    
    window_mean = np.concatenate((window_mean,[len(games_window)])) #Add column of N_games in time window
    
    window_arr.append(window_mean)
    
window_arr = np.array(window_arr)
# Out:
# On index 0, player is (William) Tony Parker
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:30: RuntimeWarning: invalid value encountered in long_scalars
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:31: RuntimeWarning: invalid value encountered in long_scalars
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:32: RuntimeWarning: invalid value encountered in true_divide
# On index 10000, player is Andre Drummond
# On index 20000, player is Ben McLemore
# On index 30000, player is Buddy Hield
# On index 40000, player is Chris Wright (b)
# On index 50000, player is Dante Cunningham
# On index 60000, player is Dennis Smith Jr.
# On index 70000, player is Dwayne Bacon
# On index 80000, player is Evan Fournier
# On index 90000, player is Greg Monroe
# On index 100000, player is J.R. Smith
# On index 110000, player is Jarrett Allen
# On index 120000, player is Jimmy Butler
# On index 130000, player is Jordan Hill
# On index 140000, player is Kemba Walker
# On index 150000, player is Kurt Thomas
# On index 160000, player is Louis Williams
# On index 170000, player is Mario Chalmers
# On index 180000, player is Mike Conley Jr.
# On index 190000, player is Nikola Mirotic
# On index 200000, player is Paul Millsap
# On index 210000, player is Robert Covington
# On index 220000, player is Serge Ibaka
# On index 230000, player is T.J. McConnell
# On index 240000, player is Tony Allen
# On index 250000, player is Victor Oladipo

# %% [markdown]
# #### Add this on to our exisiting dataframe, and save the result

# %%
inj_window = inj_df.copy()

averaged_columns = inj_df.columns[9:30]

for i,col in enumerate(averaged_columns):
    col_tag = col + "_Av14"
    inj_window[col_tag] = window_arr[:,i]
    
inj_window['N_games_14'] = window_arr[:,-1]

# %%
inj_window.to_csv('injs_avg14.csv')

# %% [markdown]
# ### 21 day window

# %%
time_window = datetime.timedelta(days=21) #Changes the time window

window_arr = []

for idx in range(inj_df.shape[0]):
    
    idx_end = idx
    idx_start = idx

    current_row = inj_df.iloc[idx]
    date_game = str2datetime(current_row['Date'])
    
    if idx%10000==0:
        print("On index {}, player is {}".format(idx,current_row['Name']))

    in_window = True

    while(in_window):
        #Run backwards through dataframe, finding the first game that's out of the window or is a different player
        row = inj_df.iloc[idx_end-1]
        in_window = (current_row['Name'] == row['Name']) and (date_game - str2datetime(row['Date']) <= time_window)
        if in_window:
            idx_end -= 1

    games_window = inj_df.iloc[idx_end:idx_start].loc[:,'MP':'+/-']
    
    window_mean = games_window.mean()
    
    #Correctly compute average FG%, 3P%, FT%
    window_mean['FG%'] = games_window['FG'].sum()/games_window['FGA'].sum()
    window_mean['3P%'] = games_window['3P'].sum()/games_window['3PA'].sum()
    window_mean['FT%'] = games_window['FT'].sum()/games_window['FT%'].sum()
    
    window_mean = np.concatenate((window_mean,[len(games_window)])) #Add column of N_games in time window
    
    window_arr.append(window_mean)
    
window_arr = np.array(window_arr)
# Out:
# On index 0, player is (William) Tony Parker
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:30: RuntimeWarning: invalid value encountered in long_scalars
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:31: RuntimeWarning: invalid value encountered in long_scalars
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:32: RuntimeWarning: invalid value encountered in true_divide
# On index 10000, player is Andre Drummond
# On index 20000, player is Ben McLemore
# On index 30000, player is Buddy Hield
# On index 40000, player is Chris Wright (b)
# On index 50000, player is Dante Cunningham
# On index 60000, player is Dennis Smith Jr.
# On index 70000, player is Dwayne Bacon
# On index 80000, player is Evan Fournier
# On index 90000, player is Greg Monroe
# On index 100000, player is J.R. Smith
# On index 110000, player is Jarrett Allen
# On index 120000, player is Jimmy Butler
# On index 130000, player is Jordan Hill
# On index 140000, player is Kemba Walker
# On index 150000, player is Kurt Thomas
# On index 160000, player is Louis Williams
# On index 170000, player is Mario Chalmers
# On index 180000, player is Mike Conley Jr.
# On index 190000, player is Nikola Mirotic
# On index 200000, player is Paul Millsap
# On index 210000, player is Robert Covington
# On index 220000, player is Serge Ibaka
# On index 230000, player is T.J. McConnell
# On index 240000, player is Tony Allen
# On index 250000, player is Victor Oladipo

# %% [markdown]
# #### Add this on to our exisiting dataframe, and save the result

# %%
inj_window = inj_df.copy()

averaged_columns = inj_df.columns[9:30]

for i,col in enumerate(averaged_columns):
    col_tag = col + "_Av21"
    inj_window[col_tag] = window_arr[:,i]
    
inj_window['N_games_21'] = window_arr[:,-1]

# %%
inj_window.to_csv('injs_avg21.csv')

# %% [markdown]
# ### Back to Back Games

# %%
time_window = datetime.timedelta(days=1) #Changes the time window

window_arr = []

for idx in range(inj_df.shape[0]):
    
    idx_end = idx
    idx_start = idx

    current_row = inj_df.iloc[idx]
    date_game = str2datetime(current_row['Date'])
    
    if idx%10000==0:
        print("On index {}, player is {}".format(idx,current_row['Name']))

    in_window = True

    while(in_window):
        #Run backwards through dataframe, finding the first game that's out of the window or is a different player
        row = inj_df.iloc[idx_end-1]
        in_window = (current_row['Name'] == row['Name']) and (date_game - str2datetime(row['Date']) <= time_window)
        if in_window:
            idx_end -= 1

    games_window = inj_df.iloc[idx_end:idx_start].loc[:,'MP':'+/-']
    
    window_mean = games_window.mean()
    
    #Correctly compute average FG%, 3P%, FT%
    window_mean['FG%'] = games_window['FG'].sum()/games_window['FGA'].sum()
    window_mean['3P%'] = games_window['3P'].sum()/games_window['3PA'].sum()
    window_mean['FT%'] = games_window['FT'].sum()/games_window['FT%'].sum()
    
    window_mean = np.concatenate((window_mean,[len(games_window)])) #Add column of N_games in time window
    
    window_arr.append(window_mean)
    
window_arr = np.array(window_arr)
# Out:
# On index 0, player is (William) Tony Parker
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:30: RuntimeWarning: invalid value encountered in long_scalars
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:31: RuntimeWarning: invalid value encountered in long_scalars
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:32: RuntimeWarning: invalid value encountered in true_divide
# On index 10000, player is Andre Drummond
# On index 20000, player is Ben McLemore
# On index 30000, player is Buddy Hield
# On index 40000, player is Chris Wright (b)
# On index 50000, player is Dante Cunningham
# On index 60000, player is Dennis Smith Jr.
# On index 70000, player is Dwayne Bacon
# On index 80000, player is Evan Fournier
# On index 90000, player is Greg Monroe
# On index 100000, player is J.R. Smith
# On index 110000, player is Jarrett Allen
# On index 120000, player is Jimmy Butler
# On index 130000, player is Jordan Hill
# On index 140000, player is Kemba Walker
# On index 150000, player is Kurt Thomas
# On index 160000, player is Louis Williams
# On index 170000, player is Mario Chalmers
# On index 180000, player is Mike Conley Jr.
# On index 190000, player is Nikola Mirotic
# On index 200000, player is Paul Millsap
# On index 210000, player is Robert Covington
# On index 220000, player is Serge Ibaka
# On index 230000, player is T.J. McConnell
# On index 240000, player is Tony Allen
# On index 250000, player is Victor Oladipo

# %% [markdown]
# #### Add this on to our exisiting dataframe, and save the result

# %%
inj_window = inj_df.copy()

averaged_columns = inj_df.columns[9:30]

for i,col in enumerate(averaged_columns):
    col_tag = col + "_b2b"
    inj_window[col_tag] = window_arr[:,i]
    
inj_window['b2b'] = window_arr[:,-1]

# %%
inj_window.to_csv('injs_b2b.csv')

# %% [markdown]
# ## Combine all the dataframes together

# %%
inj_df1 = pd.read_csv('injs_avg7.csv')
inj_df1 = inj_df1.drop(columns='Unnamed: 0')

inj_df2 = pd.read_csv('injs_avg14.csv')
inj_df2 = inj_df2.drop(columns='Unnamed: 0')

inj_df3 = pd.read_csv('injs_avg21.csv')
inj_df3 = inj_df3.drop(columns='Unnamed: 0')

inj_df4 = pd.read_csv('injs_b2b.csv')
inj_df4 = inj_df4.drop(columns='Unnamed: 0')

# %%
same_cols = [c for c in inj_df1.columns[:32]]

# %%
tmp = inj_df1.merge(inj_df2,how='inner',left_on=same_cols,right_on=same_cols)
tmp2 = tmp.merge(inj_df3,how='inner',left_on=same_cols,right_on=same_cols)
full_df = tmp2.merge(inj_df4,how='inner',left_on=same_cols,right_on=same_cols)

# %%
full_df.to_csv('inj_all_windows.csv')

# %%
for c in full_df.columns:
    print(c)
# Out:
# Name
# Height [cm]
# Weight [kg]
# Position
# Pos3
# Shoots
# Date
# Age
# Opp
# MP
# FG
# FGA
# FG%
# 3P
# 3PA
# 3P%
# FT
# FTA
# FT%
# ORB
# DRB
# TRB
# AST
# STL
# BLK
# TOV
# PF
# PTS
# GmSc
# +/-
# Was_Injured?
# Notes
# MP_Av7
# FG_Av7
# FGA_Av7
# FG%_Av7
# 3P_Av7
# 3PA_Av7
# 3P%_Av7
# FT_Av7
# FTA_Av7
# FT%_Av7
# ORB_Av7
# DRB_Av7
# TRB_Av7
# AST_Av7
# STL_Av7
# BLK_Av7
# TOV_Av7
# PF_Av7
# PTS_Av7
# GmSc_Av7
# +/-_Av7
# N_games_7
# MP_Av14
# FG_Av14
# FGA_Av14
# FG%_Av14
# 3P_Av14
# 3PA_Av14
# 3P%_Av14
# FT_Av14
# FTA_Av14
# FT%_Av14
# ORB_Av14
# DRB_Av14
# TRB_Av14
# AST_Av14
# STL_Av14
# BLK_Av14
# TOV_Av14
# PF_Av14
# PTS_Av14
# GmSc_Av14
# +/-_Av14
# N_games_14
# MP_Av21
# FG_Av21
# FGA_Av21
# FG%_Av21
# 3P_Av21
# 3PA_Av21
# 3P%_Av21
# FT_Av21
# FTA_Av21
# FT%_Av21
# ORB_Av21
# DRB_Av21
# TRB_Av21
# AST_Av21
# STL_Av21
# BLK_Av21
# TOV_Av21
# PF_Av21
# PTS_Av21
# GmSc_Av21
# +/-_Av21
# N_games_21
# MP_b2b
# FG_b2b
# FGA_b2b
# FG%_b2b
# 3P_b2b
# 3PA_b2b
# 3P%_b2b
# FT_b2b
# FTA_b2b
# FT%_b2b
# ORB_b2b
# DRB_b2b
# TRB_b2b
# AST_b2b
# STL_b2b
# BLK_b2b
# TOV_b2b
# PF_b2b
# PTS_b2b
# GmSc_b2b
# +/-_b2b
# b2b
